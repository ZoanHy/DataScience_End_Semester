# %% [markdown]
# ### **Feature Engineering**

# %% [markdown]
# ### **Cài đặt thư viện**

# %%
from IPython.core.interactiveshell import InteractiveShell
from pprint import pprint
import pandas as pd
import numpy as np
import warnings
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings("ignore")
InteractiveShell.ast_node_interactivity = "all"

# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 0 ns (started: 2023-05-22 02:23:36 +07:00)

# %% [markdown]
# ### **SmallDS**

# %%
df_watch = pd.read_csv("../main copy/clean_data/big_ds.csv")

df_watch.head()
# Out:
#   Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây   Chất liệu vỏ   Xuất xứ  \
# 0      Tissot        17150000  Thép không gỉ  Thép không gỉ   Thụy Sĩ
# 1      Tissot        26775000  Thép không gỉ  Thép không gỉ   Thụy Sĩ
# 2      Orient         8491500  Thép không gỉ  Thép không gỉ  Nhật Bản
# 3      Orient         5880000  Thép không gỉ  Thép không gỉ  Nhật Bản
# 4      Tissot        34650000         Dây da  Thép không gỉ   Thụy Sĩ
#
#   Giới tính Chất liệu mặt kính  Độ chịu nước (ATM) Bảo hành   Kiểu máy  \
# 0       NaN      Kính sapphire                10.0        2     Quartz
# 1        Nữ      Kính sapphire                 3.0        2  Automatic
# 2       Nam      Kính sapphire                 5.0        1  Automatic
# 3       Nam          Kính cứng                 5.0        1  Automatic
# 4        Nữ      Kính sapphire                 5.0        2     Quartz
#
#    Kích cỡ (mm)
# 0          39.0
# 1          32.0
# 2          41.0
# 3          41.6
# 4          31.6
# time: 31 ms (started: 2023-05-22 02:23:36 +07:00)

# %%
df_watch.shape
# Out:
# (10000, 11)
# time: 0 ns (started: 2023-05-22 02:23:36 +07:00)

# %%
df_watch.dtypes
# Out:
# Thương hiệu            object
# Giá tiền (VNĐ)          int64
# Chất liệu dây          object
# Chất liệu vỏ           object
# Xuất xứ                object
# Giới tính              object
# Chất liệu mặt kính     object
# Độ chịu nước (ATM)    float64
# Bảo hành               object
# Kiểu máy               object
# Kích cỡ (mm)          float64
# dtype: object
# time: 16 ms (started: 2023-05-22 02:23:36 +07:00)

# %%
df_watch.isna().sum()
# Out:
# Thương hiệu           234
# Giá tiền (VNĐ)          0
# Chất liệu dây         283
# Chất liệu vỏ          363
# Xuất xứ               200
# Giới tính              46
# Chất liệu mặt kính     28
# Độ chịu nước (ATM)    125
# Bảo hành               95
# Kiểu máy               17
# Kích cỡ (mm)          185
# dtype: int64
# time: 32 ms (started: 2023-05-22 02:23:36 +07:00)

# %% [markdown]
# - Các cột null ở mức độ tương đối

# %% [markdown]
# Chuyển kiểu dữ liệu cột giá tiền

# %%
df_watch["Giá tiền (VNĐ)"] = df_watch["Giá tiền (VNĐ)"].astype(float)
# Out:
# time: 0 ns (started: 2023-05-22 02:23:37 +07:00)

# %% [markdown]
# ### Điền miss value theo giá trị hay xuất hiện nhất

# %%
df_watch = df_watch.apply(lambda x: x.fillna(x.value_counts().index[0]))
# Out:
# time: 31 ms (started: 2023-05-22 02:23:37 +07:00)

# %%
df_watch.isnull().sum()
# Out:
# Thương hiệu           0
# Giá tiền (VNĐ)        0
# Chất liệu dây         0
# Chất liệu vỏ          0
# Xuất xứ               0
# Giới tính             0
# Chất liệu mặt kính    0
# Độ chịu nước (ATM)    0
# Bảo hành              0
# Kiểu máy              0
# Kích cỡ (mm)          0
# dtype: int64
# time: 16 ms (started: 2023-05-22 02:23:37 +07:00)

# %% [markdown]
# Processing Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder

name_cols_numeric = [
    "Giá tiền (VNĐ)",
    "Độ chịu nước (ATM)",
    "Kích cỡ (mm)",
]

name_cols = list(df_watch.columns)

for val in name_cols:
    if val in name_cols_numeric:
        name_cols.remove(val)

name_cols_cate = name_cols


def encoding_category_col(df, lst_col):
    for val in lst_col:
        le = LabelEncoder()
        df[val] = le.fit_transform(df[val])

    return df


df_watch = encoding_category_col(df_watch, name_cols_cate)

df_watch.head()
# Out:
#    Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ  Xuất xứ  \
# 0           57      17150000.0             14             5        5
# 1           57      26775000.0             14             5        5
# 2           42       8491500.0             14             5        2
# 3           42       5880000.0             14             5        2
# 4           57      34650000.0              1             5        5
#
#    Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 0          0                   6                10.0         3         7
# 1          1                   6                 3.0         3         0
# 2          0                   6                 5.0         0         0
# 3          0                   1                 5.0         0         0
# 4          1                   6                 5.0         3         7
#
#    Kích cỡ (mm)
# 0          39.0
# 1          32.0
# 2          41.0
# 3          41.6
# 4          31.6
# time: 31 ms (started: 2023-05-22 02:23:37 +07:00)

# %% [markdown]
# Train & Test Dataset

# %%
from sklearn.model_selection import train_test_split

train_ds, test_ds = train_test_split(df_watch, test_size=0.2, random_state=0)
# Out:
# time: 16 ms (started: 2023-05-22 02:23:37 +07:00)

# %% [markdown]
# Distribution train_ds

# %%
for c in list(df_watch.columns.drop(["Giá tiền (VNĐ)"])):
    fig, ax = plt.subplots(1, 2, figsize=(20, 6))
    ax1 = plt.subplot(121)

    ax1 = train_ds[c].plot(kind="kde")
    ax1.set_title(f"{c} - train")

    ax2 = plt.subplot(122)
    ax2 = test_ds[c].plot(kind="kde")
    ax2.set_title(f"{c} - test")


plt.show();
# Out:
# time: 7.05 s (started: 2023-05-22 02:23:37 +07:00)

# %% [markdown]
# Outlier processing

# %%
def outlier_processing(X):
    for name_col in list(X.columns):
        upper_bound = X[name_col].mean() + 3 * X[name_col].std()
        lower_bound = X[name_col].mean() - 3 * X[name_col].std()

        X.loc[X[name_col] < lower_bound, name_col] = lower_bound
        X.loc[X[name_col] > upper_bound, name_col] = upper_bound

        return X

    return X
# Out:
# time: 0 ns (started: 2023-05-22 02:23:44 +07:00)

# %%
train_ds = outlier_processing(train_ds)

train_ds.head()

for c in list(train_ds.columns):
    train_ds[c].plot(kind="kde")
    plt.title(c)
    plt.show()
# Out:
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ  Xuất xứ  \
# 7389         50.0       6570000.0             10             5        2
# 9275         12.0       2499000.0             14             5        2
# 2995          9.0       1762000.0             14             5        2
# 5316         43.0       5833800.0             14             5        7
# 356          46.0       1177200.0             13             3        7
#
#       Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 7389          0                   1                10.0         0         0
# 9275          1                   1                 3.0         0         7
# 2995          0                   5                 3.0         0         7
# 5316          0                   6                 5.0         3         7
# 356           0                   1                 3.0         0         7
#
#       Kích cỡ (mm)
# 7389          39.4
# 9275          40.0
# 2995          38.6
# 5316          42.0
# 356           37.0
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Thương hiệu')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Giá tiền (VNĐ)')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Chất liệu dây')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Chất liệu vỏ')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Xuất xứ')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Giới tính')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Chất liệu mặt kính')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Độ chịu nước (ATM)')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Bảo hành')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Kiểu máy')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Kích cỡ (mm)')
# time: 4.33 s (started: 2023-05-22 02:23:44 +07:00)

# %% [markdown]
# Normalize data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

cols_need_normalize = list(train_ds.drop('Giá tiền (VNĐ)', axis=1).columns)

train_ds[cols_need_normalize] = scaler.fit_transform(train_ds[cols_need_normalize])
test_ds[cols_need_normalize] = scaler.fit_transform(test_ds[cols_need_normalize])

train_ds.head()
test_ds.head()
# Out:
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ   Xuất xứ  \
# 7389     1.237118       6570000.0       0.195277      0.200158 -0.841657
# 9275    -1.011273       2499000.0       0.830905      0.200158 -0.841657
# 2995    -1.188778       1762000.0       0.830905      0.200158 -0.841657
# 5316     0.822941       5833800.0       0.830905      0.200158  1.175133
# 356      1.000445       1177200.0       0.671998     -3.964385  1.175133
#
#       Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 7389  -0.725954           -1.204612            1.089379 -1.106393  -1.23917
# 9275   1.377498           -1.204612           -0.692836 -1.106393   0.86169
# 2995  -0.725954            0.447522           -0.692836 -1.106393   0.86169
# 5316  -0.725954            0.860555           -0.183632  0.801318   0.86169
# 356   -0.725954           -1.204612           -0.692836 -1.106393   0.86169
#
#       Kích cỡ (mm)
# 7389      0.340852
# 9275      0.439533
# 2995      0.209278
# 5316      0.768469
# 356      -0.053871
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ   Xuất xứ  \
# 9394     0.119572      64687500.0       0.818680       0.19943  0.373615
# 898     -0.174869      10440000.0      -1.257364       0.19943  2.365163
# 2398    -0.999303       7800000.0       0.818680       0.19943 -0.821315
# 5906     1.238448       7460000.0       0.818680       0.19943 -0.821315
# 2343     0.649566       4370000.0       0.818680       0.19943 -0.821315
#
#       Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 9394  -0.731382            0.864839           -0.636965  2.061268 -1.240568
# 898   -0.731382           -1.203164           -0.151010  0.802478 -1.240568
# 2398   1.367275            0.864839           -0.151010 -1.085706 -0.639591
# 5906   1.367275           -1.203164           -0.151010 -1.085706  0.862854
# 2343  -0.731382            0.864839           -0.151010  0.802478 -1.240568
#
#       Kích cỡ (mm)
# 9394      0.805316
# 898       0.481774
# 2398     -1.508008
# 5906     -0.812393
# 2343      0.481774
# time: 31 ms (started: 2023-05-22 02:23:48 +07:00)

# %%
from sklearn.metrics import mean_squared_error

X_train = train_ds.drop(["Giá tiền (VNĐ)"], axis=1)
y_train = train_ds["Giá tiền (VNĐ)"]
X_test = test_ds.drop("Giá tiền (VNĐ)", axis=1)
y_test = test_ds["Giá tiền (VNĐ)"]
# Out:
# time: 0 ns (started: 2023-05-22 02:23:48 +07:00)

# %% [markdown]
# Tree Decision to to select feature

# %%
from sklearn.tree import DecisionTreeRegressor
dtree = DecisionTreeRegressor()

dtree.fit(X_train, y_train)

imp_df = pd.DataFrame(
    {"Feature Name": X_train.columns, "Importance": dtree.feature_importances_}
)

fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(12)
plt.figure(figsize=(10, 6))
sns.barplot(data=fi2, x="Importance", y="Feature Name")
plt.title("Feature Importance Each Attributes (Decision Tree Regressor)")

plt.xlabel("Importance")
plt.ylabel("Feature Name")
plt.show();
# Out:
# time: 250 ms (started: 2023-05-22 02:23:48 +07:00)

# %%
top_7_features = list(fi.head(7)["Feature Name"])

top_7_features.append('Giá tiền (VNĐ)')
# Out:
# time: 0 ns (started: 2023-05-22 02:23:49 +07:00)

# %%
train_ds_select_feats = train_ds[top_7_features]
test_ds_select_feats = test_ds[top_7_features]
# Out:
# time: 0 ns (started: 2023-05-22 02:23:49 +07:00)

# %%
train_ds_select_feats.shape
test_ds_select_feats.shape
# Out:
# (8000, 8)
# (2000, 8)
# time: 0 ns (started: 2023-05-22 02:23:49 +07:00)

# %%
train_ds_select_feats.to_csv('train_ds_big_process.csv', index=False)
test_ds_select_feats.to_csv('test_ds_big_process.csv', index=False)
# Out:
# time: 93 ms (started: 2023-05-22 02:23:49 +07:00)
