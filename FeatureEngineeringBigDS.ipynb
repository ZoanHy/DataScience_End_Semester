# %% [markdown]
# ### **Feature Engineering**

# %% [markdown]
# ### **Cài đặt thư viện**

# %%
from IPython.core.interactiveshell import InteractiveShell
from pprint import pprint
import pandas as pd
import numpy as np
import warnings
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns


warnings.filterwarnings("ignore")
InteractiveShell.ast_node_interactivity = "all"

# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 0 ns (started: 2023-05-22 03:26:49 +07:00)

# %% [markdown]
# ### **SmallDS**

# %%
df_watch = pd.read_csv("../main copy/clean_data/big_ds.csv")

df_watch.head()
# Out:
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây   Chất liệu vỏ   Xuất xứ  \
# 0         Lobinni         1800000         Dây da  Thép không gỉ   Thụy Sĩ
# 1  Jacques Lemans         9108000  Thép không gỉ  Thép không gỉ        Áo
# 2  Claude Bernard         2750000         Dây da  Thép không gỉ   Thụy Sĩ
# 3            Doxa       154930000         Dây da  Thép không gỉ   Thụy Sĩ
# 4           Seiko         6380000  Thép không gỉ  Thép không gỉ  Nhật Bản
#
#   Giới tính Chất liệu mặt kính  Độ chịu nước (ATM) Bảo hành   Kiểu máy  \
# 0        Nữ      Kính sapphire                 3.0        2        Pin
# 1       Nam       Kính hardlex                10.0        2  Automatic
# 2       Nam      Kính sapphire                 5.0        2     Quartz
# 3       Nam      Kính sapphire                 5.0        2  Automatic
# 4       Nam          Kính cứng                10.0        1     Quartz
#
#    Kích cỡ (mm)
# 0          34.0
# 1          42.0
# 2          40.5
# 3          42.0
# 4          42.0
# time: 47 ms (started: 2023-05-22 03:26:49 +07:00)

# %%
df_watch.shape
# Out:
# (10000, 11)
# time: 0 ns (started: 2023-05-22 03:26:49 +07:00)

# %%
df_watch.dtypes
# Out:
# Thương hiệu            object
# Giá tiền (VNĐ)          int64
# Chất liệu dây          object
# Chất liệu vỏ           object
# Xuất xứ                object
# Giới tính              object
# Chất liệu mặt kính     object
# Độ chịu nước (ATM)    float64
# Bảo hành               object
# Kiểu máy               object
# Kích cỡ (mm)          float64
# dtype: object
# time: 0 ns (started: 2023-05-22 03:26:49 +07:00)

# %%
df_watch.isna().sum()
# Out:
# Thương hiệu           244
# Giá tiền (VNĐ)          0
# Chất liệu dây         293
# Chất liệu vỏ          378
# Xuất xứ               189
# Giới tính              55
# Chất liệu mặt kính     36
# Độ chịu nước (ATM)    115
# Bảo hành               85
# Kiểu máy               21
# Kích cỡ (mm)          168
# dtype: int64
# time: 16 ms (started: 2023-05-22 03:26:49 +07:00)

# %% [markdown]
# - Các cột null ở mức độ tương đối

# %% [markdown]
# Chuyển kiểu dữ liệu cột giá tiền

# %%
df_watch["Giá tiền (VNĐ)"] = df_watch["Giá tiền (VNĐ)"].astype(float)
# Out:
# time: 16 ms (started: 2023-05-22 03:26:50 +07:00)

# %% [markdown]
# ### Điền miss value theo giá trị hay xuất hiện nhất

# %%
df_watch = df_watch.apply(lambda x: x.fillna(x.value_counts().index[0]))
# Out:
# time: 31 ms (started: 2023-05-22 03:26:50 +07:00)

# %%
df_watch.isnull().sum()
# Out:
# Thương hiệu           0
# Giá tiền (VNĐ)        0
# Chất liệu dây         0
# Chất liệu vỏ          0
# Xuất xứ               0
# Giới tính             0
# Chất liệu mặt kính    0
# Độ chịu nước (ATM)    0
# Bảo hành              0
# Kiểu máy              0
# Kích cỡ (mm)          0
# dtype: int64
# time: 16 ms (started: 2023-05-22 03:26:50 +07:00)

# %% [markdown]
# Processing Categorical Features

# %%
from sklearn.preprocessing import LabelEncoder

name_cols_numeric = [
    "Giá tiền (VNĐ)",
    "Độ chịu nước (ATM)",
    "Kích cỡ (mm)",
]

name_cols = list(df_watch.columns)

for val in name_cols:
    if val in name_cols_numeric:
        name_cols.remove(val)

name_cols_cate = name_cols


def encoding_category_col(df, lst_col):
    for val in lst_col:
        le = LabelEncoder()
        df[val] = le.fit_transform(df[val])

    return df


df_watch = encoding_category_col(df_watch, name_cols_cate)

df_watch.head()
# Out:
#    Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ  Xuất xứ  \
# 0           30       1800000.0              1             5        5
# 1           26       9108000.0             13             5       10
# 2           13       2750000.0              1             5        5
# 3           16     154930000.0              1             5        5
# 4           49       6380000.0             13             5        2
#
#    Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 0          1                   5                 3.0         3         6
# 1          0                   2                10.0         3         0
# 2          0                   5                 5.0         3         7
# 3          0                   5                 5.0         3         0
# 4          0                   1                10.0         0         7
#
#    Kích cỡ (mm)
# 0          34.0
# 1          42.0
# 2          40.5
# 3          42.0
# 4          42.0
# time: 15 ms (started: 2023-05-22 03:26:50 +07:00)

# %% [markdown]
# Train & Test Dataset

# %%
from sklearn.model_selection import train_test_split

train_ds, test_ds = train_test_split(df_watch, test_size=0.2, random_state=0)
# Out:
# time: 0 ns (started: 2023-05-22 03:26:50 +07:00)

# %% [markdown]
# Distribution train_ds

# %%
for c in list(df_watch.columns.drop(["Giá tiền (VNĐ)"])):
    fig, ax = plt.subplots(1, 2, figsize=(20, 6))
    ax1 = plt.subplot(121)

    ax1 = train_ds[c].plot(kind="kde")
    ax1.set_title(f"{c} - train")

    ax2 = plt.subplot(122)
    ax2 = test_ds[c].plot(kind="kde")
    ax2.set_title(f"{c} - test")


plt.show();
# Out:
# time: 5.12 s (started: 2023-05-22 03:26:50 +07:00)

# %% [markdown]
# Outlier processing

# %%
def outlier_processing(X):
    for name_col in list(X.columns):
        upper_bound = X[name_col].mean() + 3 * X[name_col].std()
        lower_bound = X[name_col].mean() - 3 * X[name_col].std()

        X.loc[X[name_col] < lower_bound, name_col] = lower_bound
        X.loc[X[name_col] > upper_bound, name_col] = upper_bound

        return X

    return X
# Out:
# time: 0 ns (started: 2023-05-22 03:26:55 +07:00)

# %%
train_ds = outlier_processing(train_ds)

train_ds.head()

for c in list(train_ds.columns):
    train_ds[c].plot(kind="kde")
    plt.title(c)
    plt.show()
# Out:
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ  Xuất xứ  \
# 7389          4.0      19692000.0             13             5       12
# 9275         42.0       3630000.0              8             5        2
# 2995         56.0      23625000.0              1             5        5
# 5316          9.0       1243000.0             13             5        2
# 356          12.0       5800000.0              0             5        2
#
#       Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 7389          0                   5                 3.0         3         7
# 9275          0                   1                 5.0         0         7
# 2995          0                   5                10.0         3         0
# 5316          1                   1                 5.0         0         7
# 356           0                   1                10.0         0         0
#
#       Kích cỡ (mm)
# 7389          41.5
# 9275          43.0
# 2995          42.0
# 5316          30.0
# 356           45.0
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Thương hiệu')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Giá tiền (VNĐ)')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Chất liệu dây')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Chất liệu vỏ')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Xuất xứ')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Giới tính')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Chất liệu mặt kính')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Độ chịu nước (ATM)')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Bảo hành')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Kiểu máy')
# <Axes: ylabel='Density'>
# Text(0.5, 1.0, 'Kích cỡ (mm)')
# time: 3.59 s (started: 2023-05-22 03:26:55 +07:00)

# %% [markdown]
# Normalize data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

cols_need_normalize = list(train_ds.drop('Giá tiền (VNĐ)', axis=1).columns)

train_ds[cols_need_normalize] = scaler.fit_transform(train_ds[cols_need_normalize])
test_ds[cols_need_normalize] = scaler.fit_transform(test_ds[cols_need_normalize])

train_ds.head()
test_ds.head()
# Out:
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ   Xuất xứ  \
# 7389    -1.485336      19692000.0       0.836460      0.202953  3.238261
# 9275     0.799403       3630000.0      -0.023322      0.202953 -0.847744
# 2995     1.641149      23625000.0      -1.227016      0.202953  0.378058
# 5316    -1.184712       1243000.0       0.836460      0.202953 -0.847744
# 356     -1.004338       5800000.0      -1.398972      0.202953 -0.847744
#
#       Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 7389  -0.736826            0.875090           -0.701402  0.785811  0.850177
# 9275  -0.736826           -1.192306           -0.174651 -1.107900  0.850177
# 2995  -0.736826            0.875090            1.142227  0.785811 -1.256643
# 5316   1.357173           -1.192306           -0.174651 -1.107900  0.850177
# 356   -0.736826           -1.192306            1.142227 -1.107900 -1.256643
#
#       Kích cỡ (mm)
# 7389      0.690745
# 9275      0.932748
# 2995      0.771413
# 5316     -1.164607
# 356       1.255418
#       Thương hiệu  Giá tiền (VNĐ)  Chất liệu dây  Chất liệu vỏ   Xuất xứ  \
# 9394     1.184981       5110000.0      -1.257151      0.202113 -0.880195
# 898     -0.131897       6750000.0      -1.257151      0.202113  0.372751
# 2398    -1.029769       2014500.0      -1.257151      0.202113 -0.880195
# 5906    -1.628351      23355000.0       0.814933      0.202113  0.372751
# 2343     0.825833       4111200.0      -1.257151      0.202113  1.208049
#
#       Giới tính  Chất liệu mặt kính  Độ chịu nước (ATM)  Bảo hành  Kiểu máy  \
# 9394  -0.707372           -1.283854            1.054363 -1.097871  0.851429
# 898   -0.707372            0.814375           -0.177945  0.801012 -1.255696
# 2398   1.413683           -1.283854           -0.670868 -1.097871  0.851429
# 5906  -0.707372            0.814375           -0.177945  0.801012 -1.255696
# 2343  -0.707372            0.814375           -0.177945  0.801012  0.851429
#
#       Kích cỡ (mm)
# 9394      1.261463
# 898       0.611698
# 2398     -1.175158
# 5906      0.124373
# 2343      0.774139
# time: 47 ms (started: 2023-05-22 03:26:59 +07:00)

# %%
from sklearn.metrics import mean_squared_error

X_train = train_ds.drop(["Giá tiền (VNĐ)"], axis=1)
y_train = train_ds["Giá tiền (VNĐ)"]
X_test = test_ds.drop("Giá tiền (VNĐ)", axis=1)
y_test = test_ds["Giá tiền (VNĐ)"]
# Out:
# time: 0 ns (started: 2023-05-22 03:26:59 +07:00)

# %% [markdown]
# Tree Decision to to select feature

# %%
from sklearn.tree import DecisionTreeRegressor
dtree = DecisionTreeRegressor()

dtree.fit(X_train, y_train)

imp_df = pd.DataFrame(
    {"Feature Name": X_train.columns, "Importance": dtree.feature_importances_}
)

fi = imp_df.sort_values(by="Importance", ascending=False)

fi2 = fi.head(12)
plt.figure(figsize=(10, 6 ))
sns.barplot(data=fi2, x="Importance", y="Feature Name")
plt.title("Feature Importance Each Attributes (Decision Tree Regressor)")

plt.xlabel("Importance")
plt.ylabel("Feature Name")
plt.show();
# Out:
# time: 219 ms (started: 2023-05-22 03:26:59 +07:00)

# %%
top_7_features = list(fi.head(7)["Feature Name"])

top_7_features.append('Giá tiền (VNĐ)')
# Out:
# time: 0 ns (started: 2023-05-22 03:26:59 +07:00)

# %%
train_ds_select_feats = train_ds[top_7_features]
test_ds_select_feats = test_ds[top_7_features]
# Out:
# time: 16 ms (started: 2023-05-22 03:26:59 +07:00)

# %%
train_ds_select_feats.shape
test_ds_select_feats.shape
# Out:
# (8000, 8)
# (2000, 8)
# time: 0 ns (started: 2023-05-22 03:26:59 +07:00)

# %%
train_ds_select_feats.to_csv('train_ds_big_process.csv', index=False)
test_ds_select_feats.to_csv('test_ds_big_process.csv', index=False)
# Out:
# time: 94 ms (started: 2023-05-22 03:27:00 +07:00)
